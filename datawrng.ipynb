# %%
import colour
from colour import Color
import pandas as pd
import csv
ds=pd.DataFrame(columns=['Gender', 'Wear Type','Item','Sleeve Styling','Fit','Type','Length','Occasion','Print or Pattern Type','Neck','Pattern', 'Sleeve Length','desc', 'img', 'color', 'Multicolor'])

ds=pd.read_csv(r'C:\Users\Manas\Desktop\ML\PROJECT\postscrape\postscrape\m\myntra_data_updatedn.csv',error_bad_lines=False,header=None,sep='\t')

# %%
ds.columns=['Gender', 'Wear Type','Item','Sleeve Styling','Fit','Type','Length','Occasion','Print or Pattern Type','Neck','Pattern', 'Sleeve Length','desc', 'img', 'color', 'Multicolor']

# %%
ds['color']=''
ds['multicolored']=''
import numpy as np
for row in np.arange(0,len(ds.index)-1):
    d= ds['desc'][row]
    d=d.replace(',', '')
    s=','.join([i for i in d.split(' ') if check_color(i)])
    ds['color'][row]=s
    if s.count(",") > 0:
        
        ds['multicolored'][row]='Y'
    else:
        ds['multicolored'][row]='N'

# %%
def check_color(color):
    try:
        Color(color)
        return True
    except ValueError:
        return False

# %%
ds= ds.drop_duplicates(subset='img', keep='first', inplace=False)

# %%
ds = ds.reset_index(drop=True)

# %%
ds.head()
# Out:
#   Gender Wear Type     Item   Sleeve Styling  Fit Type Length Occasion  \
# 0   male   topwear  Tshirts  Regular Sleeves  NaN  NaN    NaN   Casual
# 1   male   topwear  Tshirts  Regular Sleeves  NaN  NaN    NaN   Casual
# 2   male   topwear  Tshirts  Regular Sleeves  NaN  NaN    NaN   Casual
# 3   male   topwear  Tshirts  Regular Sleeves  NaN  NaN    NaN   Casual
# 4   male   topwear  Tshirts  Regular Sleeves  NaN  NaN    NaN   Casual
#
#   Print or Pattern Type Neck        Pattern  Sleeve Length  \
# 0         Colourblocked  NaN  Colourblocked  Short Sleeves
# 1         Colourblocked  NaN  Colourblocked  Short Sleeves
# 2               Striped  NaN          Solid   Long Sleeves
# 3               Striped  NaN          Solid   Long Sleeves
# 4            Typography  NaN        Printed  Short Sleeves
#
#                                                 desc  \
# 0  Navy Blue and green colourblocked T-shirt, has...
# 1  Navy Blue and green colourblocked T-shirt, has...
# ...

# %%
c= ds.loc[1,'desc']
c=c.replace(',', '')
s=','.join([i for i in c.split(' ') if check_color(i)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-b61d0be46fa3> in <module>
# ----> 1 c= ds.loc[1,'desc']
# ...

# %%
s.count(",")
# Out:
# 'Navy,Blue,green'

# %%
for i in np.arange(0,len(ds.index)):
    print(ds.loc['desc'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'desc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-d4437db4210f> in <module>
#       1 for i in np.arange(0,len(ds.index)):
# ----> 2     print(ds.loc['desc'])
#
# ...

# %%
len(ds.index)
# Out:
# 7614

# %%
ds['color']=''

# %%
ds.head()
# Out:
#      1        2        3                4    5    6    7       8   \
# 0  male  topwear  Tshirts  Regular Sleeves  NaN  NaN  NaN  Casual
# 1  male  topwear  Tshirts  Regular Sleeves  NaN  NaN  NaN  Casual
# 2  male  topwear  Tshirts  Regular Sleeves  NaN  NaN  NaN  Casual
# 3  male  topwear  Tshirts  Regular Sleeves  NaN  NaN  NaN  Casual
# 4  male  topwear  Tshirts  Regular Sleeves  NaN  NaN  NaN  Casual
#
#               9    10             11             12  \
# 0  Colourblocked  NaN  Colourblocked  Short Sleeves
# 1  Colourblocked  NaN  Colourblocked  Short Sleeves
# 2        Striped  NaN          Solid   Long Sleeves
# 3        Striped  NaN          Solid   Long Sleeves
# 4     Typography  NaN        Printed  Short Sleeves
#
#                                                   13  \
# 0  Navy Blue and green colourblocked T-shirt, has...
# 1  Navy Blue and green colourblocked T-shirt, has...
# 2  Sea Green solid T-shirt, has a round neck, and...
# ...

# %%
del ds[0]

# %%
ds.to_csv("Merged.csv", sep='\t', encoding='utf-8', mode='a', header=True)

# %%
import os, glob
import pandas as pd

path = r"C:\Users\Manas\Desktop\ML\PROJECT\postscrape\postscrape\m"

all_files = glob.glob(os.path.join(path, "*.csv"))

all_df = []
for f in all_files:
    df = pd.read_csv(f, sep='\t', header=0)
    df['file'] = f.split('\t')[-1]
    all_df.append(df)
    
merged_df = pd.concat(all_df, ignore_index=True, sort=True)

# %%
len(merged_df.index)
# Out:
# 18448

# %%
merged_df.head()
# Out:
#    0  \
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
#
#   4d826b89-0119-4c89-8861-4a8cea8ed0691548844555754-DILLINGER-Men-Navy-Blue-Colourblocked-Round-Neck-T-shirt-161-1.jpg  \
# 0  11518159758071-FIDO-DIDO-Men-Tshirts-959151815...
# 1  26d874f1-6a39-4ef3-909a-98a8f96269c61582800381...
# 2  36b31d03-3ec1-4596-9f56-460313a9f9111582800381...
# 3  29bdd2c8-3e2f-43aa-8ce5-55f3a501a4fa1577166621...
# 4  7255ad96-4bf3-49a6-b5e4-975e50c278861580946249...
#
#   6250b59b-fbf4-421e-9b36-e0200e3c3a4b1574857500113-DILLINGER-Men-Sweatshirts-4431574857498487-1.jpg  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   72453a34-4e8f-41f6-a737-4e4e52a1fd1b1580948277023-1.jpg  \
# 0                                                NaN
# ...

# %%
tar xzf cifar.tgz
# Out:
#   File "<ipython-input-58-bd2b7831fe61>", line 1
#     tar xzf cifar.tgz
#           ^
# SyntaxError: invalid syntax

# %%
import PIL
from PIL import Image

# %%
basewidth = 32
img = Image.open('a49328b3-3ec6-4e4a-90a1-5481b07200db1559972663298-Nike-Men-Black-Solid-Sporty-Jacket-3701559972661629-1.jpg')

img = img.resize((basewidth, basewidth), PIL.Image.ANTIALIAS)
img.save('Aresized_image2.jpg')
